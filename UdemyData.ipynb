# %% [markdown]
# ### <span style="color:violet;">Udemy Dataset</span>

# %%
import pandas as pd

# %%
udemydata = pd.read_csv('data/udemy_courses.csv')
udemydata
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
udemydata.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
udemydata.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# ### Different subject offered in Udemy

# %%
udemydata.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %% [markdown]
# ### Subject with max no of courses

# %%
udemydata.subject.value_counts()
#udemydata.subject.value_counts().max()
# This shows that web development is the maximum with 1200
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# ### show courses that are free

# %%
#udemydata.head(1)
udemydata[udemydata.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %% [markdown]
# ### courses that are paid

# %%
udemydata[udemydata.is_paid == True]
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# ### Top selling courses(many subscribers)

# %%
udemydata.sort_values('num_subscribers', ascending=False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1569     726314       Create Beautiful Image Maps for Your Website
# 1473     185526                             MicroStation - Células
# 1472     181268               Photoshop: Creando elemental de aire
# 1471     188584                        Letras en Adobe Illustrator
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %% [markdown]
# ### Courses of Web Development From Scratch where price is below 100

# %%
udemydata[(udemydata.subject == 'Web Development') & (udemydata.price < 100)]
# Out:
#       course_id                                       course_title  \
# 2478      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
# 2479      19603  Learning Dynamic Website Design - PHP MySQL an...
# 2480     889438  ChatBots: Messenger ChatBot with API.AI and No...
# 2481     197836                                  Projects in HTML5
# 2482     505208  Programming Foundations: HTML5 + CSS3 for Entr...
# ...         ...                                                ...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 2478  https://www.udemy.com/build-beautiful-html5-we...     True     75
# ...

# %% [markdown]
# ### Courses related to python

# %%
udemydata[udemydata.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %% [markdown]
# ### Courses that are related to HTML

# %%
udemydata[udemydata.course_title.str.contains('HTML')]
# Out:
#       course_id                                       course_title  \
# 2478      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
# 2481     197836                                  Projects in HTML5
# 2482     505208  Programming Foundations: HTML5 + CSS3 for Entr...
# 2491       8325            HTML Tutorial: HTML & CSS for Beginners
# 2494     159070              Introduction to Web Development: HTML
# ...         ...                                                ...
# 3656     654832   HTML Forms For Beginners: A Basic Introduction
# 3660     747650  Learn HTML, CSS, and Ruby on Rails: Build Your...
# 3661     761770                   Learn HTML5 Canvas for beginners
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 2478  https://www.udemy.com/build-beautiful-html5-we...     True     75
# ...

# %% [markdown]
# ### Courses that are related to css

# %%
udemydata[udemydata.course_title.str.contains('CSS')]
# Out:
#       course_id                                       course_title  \
# 2478      28295  Learn Web Designing & HTML5/CSS3 Essentials in...
# 2482     505208  Programming Foundations: HTML5 + CSS3 for Entr...
# 2491       8325            HTML Tutorial: HTML & CSS for Beginners
# 2510    1252318     The Complete HTML and CSS Course For Beginners
# 2519     736940   Practical CSS Website Development: Crash Course
# ...         ...                                                ...
# 3650     516790                HTML and CSS: A Guide to Web Design
# 3652     919354  Learn Bootstrap 4 The Most Popular HTML5 CSS3 ...
# 3660     747650  Learn HTML, CSS, and Ruby on Rails: Build Your...
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
#
#                                                     url  is_paid  price  \
# 2478  https://www.udemy.com/build-beautiful-html5-we...     True     75
# ...

# %% [markdown]
# ### Courses that are related to javascript

# %%
udemydata[udemydata.course_title.str.contains('Javascript')]
# Out:
#       course_id                                       course_title  \
# 2512     670034                                Advanced Javascript
# 2526    1124970  Javascript ES6! A Complete Reference Guide to ...
# 2532     945320  Javascript Intermediate level 2 - Mastering Fu...
# 2542     937134             Javascript Intermediate level 3 - JSON
# 2559     939962  Learn SVG Animation - With HTML, CSS & Javascript
# 2619      94430             Learn Javascript & JQuery From Scratch
# 2632     945336  Javascript Intermediate level 1 - Mastering th...
# 2669     959586         Javascript from Beginner to Advanced Level
# 2716     405818  Javascript for Beginners Learn by Doing Practi...
# 2857     783686  Byte-Sized-Chunks: Dynamic Prototypes in Javas...
# 2880     773824  Learn By Example: The Foundations of HTML, CSS...
# 2899    1169848  Build Your Own Calculator App with Javascript,...
# 2955     624578                           Javascript for beginners
# ...

# %%
udemydata.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
udemydata['published_timestamp'] = pd.to_datetime(udemydata.published_timestamp)
udemydata.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
## Add the year column
udemydata['year'] = udemydata['published_timestamp'].dt.year
udemydata.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#         published_timestamp           subject  year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017
# 1 2017-03-09 16:34:20+00:00  Business Finance  2017

# %%
udemydata[udemydata['year'] == 2015]
# Out:
#       course_id                                       course_title  \
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8        476268  Options Trading 3 : Advanced Stock Profit and ...
# 10       592338  Forex Trading Secrets of the Pros With Amazon'...
# 15       504036  Short Selling: Learn To Sell Stocks Before The...
# 17       564966  The Complete Chart Pattern Trading Course: A P...
# ...         ...                                                ...
# 3659     577796  Simple Javascript: Learn by Doing, Beginners W...
# 3667     523216  The Fastest Way to Create a Website Using Godaddy
# 3669     679992                  Building Better APIs with GraphQL
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3675     635248                      Learn and Build using Polymer
#
#                                                     url  is_paid  price  \
# 7     https://www.udemy.com/trading-chart-patterns-f...     True     95
# ...

# %%
#udemydata.head(1)
udemydata.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
