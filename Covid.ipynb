# %%
import pandas as pd

# %%
covid_data = pd.read_csv('data/COVID-19 Coronavirus.csv')
covid_data.head(20)
# Out:
#                 Country          Other names ISO 3166-1 alpha-3 CODE  \
# 0           Afghanistan          Afghanistan                     AFG
# 1               Albania              Albania                     ALB
# 2               Algeria              Algeria                     DZA
# 3               Andorra              Andorra                     AND
# 4                Angola               Angola                     AGO
# 5              Anguilla             Anguilla                     AIA
# 6   Antigua and Barbuda  Antigua and Barbuda                     ATG
# 7             Argentina            Argentina                     ARG
# 8               Armenia              Armenia                     ARM
# 9                 Aruba                Aruba                     ABW
# 10            Australia            Australia                     AUS
# 11              Austria              Austria                     AUT
# 12           Azerbaijan           Azerbaijan                     AZE
# ...

# %% [markdown]
# ### <span style="color: violet;">Checking the column with null values</span>

# %%
covid_data.count()
# Out:
# Country                    225
# Other names                224
# ISO 3166-1 alpha-3 CODE    225
# Population                 225
# Continent                  225
# Total Cases                225
# Total Deaths               225
# Tot Cases//1M pop          225
# Tot Deaths/1M pop          225
# Death percentage           225
# dtype: int64

# %%
covid_data.isnull().sum()
# Out:
# Country                    0
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# Tot Cases//1M pop          0
# Tot Deaths/1M pop          0
# Death percentage           0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
covid_data.head(1)
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
#
#    Death percentage
# 0          4.313743

# %%
sns.heatmap(covid_data.isnull())
plt.show()

# %%
#covid_data.head(1)
covid_data.groupby('Country')['Total Deaths'].sum().sort_values(ascending=False)
# Out:
# Country
# USA             1008222
# Brazil           660269
# India            521388
# Russia           369708
# Mexico           323212
#                  ...
# Vatican City          0
# Micronesia            0
# Niue                  0
# Cook Islands          0
# Saint Helena          0
# Name: Total Deaths, Length: 225, dtype: int64

# %%
#covid_data.head(1)
covid_data.groupby('Continent')[['Total Cases', 'Total Deaths']].sum()
# Out:
#                                  Total Cases  Total Deaths
# Continent
# Africa                              11764207        252873
# Asia                               140957179       1405003
# Europe                             180332483       1775727
# Latin America and the Caribbean     67509231       1686828
# Northern America                    85364770       1046062
# Oceania                              5647957          9336

# %%
covid_data[covid_data['Total Cases'] > 100000]
# Out:
#          Country                         Other names ISO 3166-1 alpha-3 CODE  \
# 0    Afghanistan                         Afghanistan                     AFG
# 1        Albania                             Albania                     ALB
# 2        Algeria                             Algeria                     DZA
# 7      Argentina                           Argentina                     ARG
# 8        Armenia                             Armenia                     ARM
# ..           ...                                 ...                     ...
# 215   Uzbekistan                          Uzbekistan                     UZB
# 218    Venezuela  Venezuela (Bolivarian Republic of)                     VEN
# 219      Vietnam                            Viet Nam                     VNM
# 223       Zambia                              Zambia                     ZMB
# 224     Zimbabwe                            Zimbabwe                     ZWE
#
# ...

# %%
# To remove the records satisfying a particular condition
covid_data = covid_data[~(covid_data['Total Cases'] > 10000)]
covid_data
# Out:
#                     Country                                 Other names  \
# 5                  Anguilla                                    Anguilla
# 6       Antigua and Barbuda                         Antigua and Barbuda
# 27   British Virgin Islands                      British Virgin Islands
# 37    Caribbean Netherlands            Bonaire, Sint Eustatius and Saba
# 39                     Chad                                        Chad
# 44                  Comoros                                     Comoros
# 46             Cook Islands                                Cook Islands
# 62                  Eritrea                                     Eritrea
# 67         Falkland Islands                 Falkland Islands (Malvinas)
# 85            Guinea-Bissau                               Guinea-Bissau
# 106                Kiribati                                    Kiribati
# 113                 Liberia                                     Liberia
# ...

# %%
covid_data.shape
# Out:
# (225, 10)

# %%
covid_data.head(2)
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
#
#    Death percentage
# 0          4.313743
# 1          1.275058

# %%
#maximum
covid_data.groupby('Continent').Population.sum().sort_values(ascending=False)
# Out:
# Continent
# Asia                               4668689344
# Africa                             1396751613
# Europe                              748420351
# Latin America and the Caribbean     661325824
# Northern America                    372846593
# Oceania                              43437948
# Name: Population, dtype: int64

# %%
#minimum no of death cases
covid_data.groupby('Country')['Total Deaths'].sum().sort_values(ascending=True)
# Out:
# Country
# Saint Helena          0
# Macao                 0
# Micronesia            0
# Cook Islands          0
# Vatican City          0
#                  ...
# Mexico           323212
# Russia           369708
# India            521388
# Brazil           660269
# USA             1008222
# Name: Total Deaths, Length: 225, dtype: int64
