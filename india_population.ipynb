# %% [markdown]
# ## <span style="color: violet;">India Population Dataset</spancd>

# %%
import pandas as pd

# %%
population = pd.read_csv('data/population.csv')
population
# Out:
#     Rank                        State             Capital   Population  \
# 0      1                Uttar Pradesh             Lucknow  199,812,341
# 1      2                  Maharashtra              Mumbai  112,374,333
# 2      3                        Bihar               Patna  104,099,452
# 3      4                  West Bengal             Kolkata   91,276,115
# 4      5               Andhra Pradesh           Hyderabad   84,580,777
# 5      6               Madhya Pradesh              Bhopal   72,626,809
# 6      7                   Tamil Nadu             Chennai   72,147,030
# 7      8                    Rajasthan              Jaipur   68,548,437
# 8      9                    Karnataka           Bengaluru   61,095,297
# 9     10                      Gujarat         Gandhinagar   60,439,692
# 10    11                       Odisha        Bhubaneshwar   41,974,218
# 11    12                       Kerala  Thiruvananthapuram   33,406,061
# ...

# %%
population.shape
# Out:
# (35, 14)

# %%
population.isnull().count()
# Out:
# Rank                     35
# State                    35
# Capital                  35
# Population               35
# % of Total Population    35
# Males                    35
# Females                  35
# Sex Ratio                35
# Literacy Rate (%)        35
# Rural Population         35
# Urban Population         35
# Area (km*km)             35
# Density (1/km*km)        35
# Decadal Growth (%)       35
# dtype: int64

# %%
population.dtypes
# Out:
# Rank                       int64
# State                     object
# Capital                   object
# Population                object
# % of Total Population    float64
# Males                     object
# Females                   object
# Sex Ratio                 object
# Literacy Rate (%)        float64
# Rural Population          object
# Urban Population          object
# Area (km*km)              object
# Density (1/km*km)         object
# Decadal Growth (%)        object
# dtype: object

# %%
population.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_96434">
#   <thead>
#     <tr>
#       <th id="T_96434_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_96434_level0_col1" class="col_heading level0 col1" >State</th>
#       <th id="T_96434_level0_col2" class="col_heading level0 col2" >Capital</th>
#       <th id="T_96434_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_96434_level0_col4" class="col_heading level0 col4" >% of Total Population</th>
#       <th id="T_96434_level0_col5" class="col_heading level0 col5" >Males</th>
#       <th id="T_96434_level0_col6" class="col_heading level0 col6" >Females</th>
#       <th id="T_96434_level0_col7" class="col_heading level0 col7" >Sex Ratio</th>
#       <th id="T_96434_level0_col8" class="col_heading level0 col8" >Literacy Rate (%)</th>
#       <th id="T_96434_level0_col9" class="col_heading level0 col9" >Rural Population</th>
# ...

# %%
population.style.set_caption('Indian Population')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9953">
#   <caption>Indian Population</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9953_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_d9953_level0_col1" class="col_heading level0 col1" >State</th>
#       <th id="T_d9953_level0_col2" class="col_heading level0 col2" >Capital</th>
#       <th id="T_d9953_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_d9953_level0_col4" class="col_heading level0 col4" >% of Total Population</th>
#       <th id="T_d9953_level0_col5" class="col_heading level0 col5" >Males</th>
#       <th id="T_d9953_level0_col6" class="col_heading level0 col6" >Females</th>
#       <th id="T_d9953_level0_col7" class="col_heading level0 col7" >Sex Ratio</th>
#       <th id="T_d9953_level0_col8" class="col_heading level0 col8" >Literacy Rate (%)</th>
# ...

# %%
population.head(1)
population[population['State'].isin(['Delhi', 'Punjab'])]
# Out:
#     Rank   State     Capital  Population  % of Total Population       Males  \
# 14    15  Punjab  Chandigarh  27,743,338                   2.29  14,639,465
# 17    18   Delhi       Delhi  16,787,941                   1.39   8,887,326
#
#        Females Sex Ratio  Literacy Rate (%) Rural Population Urban Population  \
# 14  13,103,873       895              75.84       17,316,800       10,387,436
# 17   7,800,615       868              86.21          944,727       12,905,780
#
#    Area (km*km) Density (1/km*km) Decadal Growth (%)
# 14       50,362               550              13.7%
# 17        1,484            11,297                21%

# %%
population[population.State == 'Delhi']['Females'].sum()
# Out:
# '7,800,615'

# %%
population[population.State == 'Punjab']['Males'].sum()
# Out:
# '14,639,465'

# %%
# set index column
population.set_index('Rank')
# Out:
#                             State             Capital   Population  \
# Rank
# 1                   Uttar Pradesh             Lucknow  199,812,341
# 2                     Maharashtra              Mumbai  112,374,333
# 3                           Bihar               Patna  104,099,452
# 4                     West Bengal             Kolkata   91,276,115
# 5                  Andhra Pradesh           Hyderabad   84,580,777
# 6                  Madhya Pradesh              Bhopal   72,626,809
# 7                      Tamil Nadu             Chennai   72,147,030
# 8                       Rajasthan              Jaipur   68,548,437
# 9                       Karnataka           Bengaluru   61,095,297
# 10                        Gujarat         Gandhinagar   60,439,692
# 11                         Odisha        Bhubaneshwar   41,974,218
# 12                         Kerala  Thiruvananthapuram   33,406,061
# 13                      Jharkhand              Ranchi   32,988,134
# ...

# %%
population.groupby('Capital')[['Males', 'Females']].sum()
# Out:
#                                           Males                      Females
# Capital
# Agartala                              1,874,376                    1,799,541
# Aizawl                                  555,339                      541,867
# Bengaluru                            30,966,657                   30,128,640
# Bhopal                               37,612,306                   35,014,503
# Bhubaneshwar                         21,212,136                   20,762,082
# Chandigarh          14,639,46513,494,734580,663  13,103,87311,856,728474,787
# Chennai                              36,137,975                   36,009,055
# Daman                                   150,301                       92,946
# Dehradun                              5,137,773                    4,948,519
# Delhi                                 8,887,326                    7,800,615
# Dispur                               15,939,443                   15,266,133
# ...

# %%
population.groupby('Capital').Population.min().sort_values()
# Out:
# Capital
# Chandigarh              1,055,450
# Aizawl                  1,097,206
# Pondicherry             1,247,953
# Itanagar                1,383,727
# Panaji                  1,458,545
# Kohima                  1,978,502
# Dehradun               10,086,292
# Patna                 104,099,452
# Mumbai                112,374,333
# Delhi                  16,787,941
# Lucknow               199,812,341
# Imphal                  2,721,756
# Shillong                2,966,889
# Daman                     243,247
# Raipur                 25,545,198
# Agartala                3,673,917
# Dispur                 31,205,576
# Ranchi                 32,988,134
# Thiruvananthapuram     33,406,061
# Silvassa                  343,709
# Port Blair                380,581
# Bhubaneshwar           41,974,218
# Shimla                  6,864,602
# Gandhinagar            60,439,692
# Bengaluru              61,095,297
# Gangtok                   610,577
# Kavaratti                  64,473
# ...

# %%
population.columns
# Out:
# Index(['Rank', 'State', 'Capital', 'Population', '% of Total Population',
#        'Males', 'Females', 'Sex Ratio', 'Literacy Rate (%)',
#        'Rural Population', 'Urban Population', 'Area (km*km)',
#        'Density (1/km*km)', 'Decadal Growth (%)'],
#       dtype='object')

# %%
population.loc[29, 'Chandigarh'] = 0
#population

# %%
# Adding suffix on the column names
population.add_suffix('_end')
# Out:
#     Rank_end                    State_end         Capital_end Population_end  \
# 0          1                Uttar Pradesh             Lucknow    199,812,341
# 1          2                  Maharashtra              Mumbai    112,374,333
# 2          3                        Bihar               Patna    104,099,452
# 3          4                  West Bengal             Kolkata     91,276,115
# 4          5               Andhra Pradesh           Hyderabad     84,580,777
# 5          6               Madhya Pradesh              Bhopal     72,626,809
# 6          7                   Tamil Nadu             Chennai     72,147,030
# 7          8                    Rajasthan              Jaipur     68,548,437
# 8          9                    Karnataka           Bengaluru     61,095,297
# 9         10                      Gujarat         Gandhinagar     60,439,692
# 10        11                       Odisha        Bhubaneshwar     41,974,218
# ...

# %%
# Adding Prefix
population.add_prefix('start_')
# Out:
#     start_Rank                  start_State       start_Capital  \
# 0            1                Uttar Pradesh             Lucknow
# 1            2                  Maharashtra              Mumbai
# 2            3                        Bihar               Patna
# 3            4                  West Bengal             Kolkata
# 4            5               Andhra Pradesh           Hyderabad
# 5            6               Madhya Pradesh              Bhopal
# 6            7                   Tamil Nadu             Chennai
# 7            8                    Rajasthan              Jaipur
# 8            9                    Karnataka           Bengaluru
# 9           10                      Gujarat         Gandhinagar
# 10          11                       Odisha        Bhubaneshwar
# 11          12                       Kerala  Thiruvananthapuram
# 12          13                    Jharkhand              Ranchi
# 13          14                        Assam              Dispur
# ...
